# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Importing Data
df = pd.read_csv('Musician(1).csv')

# %%
#getting the head 
df.head()
# Out:
#    Rank  Peak All Time Peak  Actual gross Adjusted gross (in 2022 dollars)  \
# 0     1     1             2  $780,000,000                     $780,000,000
# 1     2     1          7[2]  $579,800,000                     $579,800,000
# 2     3  1[4]          2[5]  $411,000,000                     $560,622,615
# 3     4  2[7]         10[7]  $397,300,000                     $454,751,555
# 4     5  2[4]           NaN  $345,675,146                     $402,844,849
#
#          Artist                   Tour title    Year(s)  Shows Average gross  \
# 0  Taylor Swift              The Eras Tour †  2023–2024     56   $13,928,571
# 1       Beyoncé       Renaissance World Tour       2023     56   $10,353,571
# 2       Madonna  Sticky & Sweet Tour ‡[4][a]  2008–2009     85    $4,835,294
# 3          Pink  Beautiful Trauma World Tour  2018–2019    156    $2,546,795
# 4  Taylor Swift      Reputation Stadium Tour       2018     53    $6,522,173
#
#   Ref.
# 0  [1]
# 1  [3]
# 2  [6]
# 3  [7]
# 4  [8]

# %%
#getting the information 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Rank                              20 non-null     int64
#  1   Peak                              9 non-null      object
#  2   All Time Peak                     6 non-null      object
#  3   Actual gross                      20 non-null     object
#  4   Adjusted gross (in 2022 dollars)  20 non-null     object
#  5   Artist                            20 non-null     object
#  6   Tour title                        20 non-null     object
#  7   Year(s)                           20 non-null     object
#  8   Shows                             20 non-null     int64
#  9   Average gross                     20 non-null     object
#  10  Ref.                              20 non-null     object
# dtypes: int64(2), object(9)
# memory usage: 1.8+ KB

# %%
#drooping columns (peak , all time peak, rank , ref)
df = df.drop(columns = ['Peak','All Time Peak','Rank', 'Ref.'])

# %%
df.head()
# Out:
#    Actual gross Adjusted gross (in 2022 dollars)        Artist  \
# 0  $780,000,000                     $780,000,000  Taylor Swift
# 1  $579,800,000                     $579,800,000       Beyoncé
# 2  $411,000,000                     $560,622,615       Madonna
# 3  $397,300,000                     $454,751,555          Pink
# 4  $345,675,146                     $402,844,849  Taylor Swift
#
#                     Tour title    Year(s)  Shows Average gross
# 0              The Eras Tour †  2023–2024     56   $13,928,571
# 1       Renaissance World Tour       2023     56   $10,353,571
# 2  Sticky & Sweet Tour ‡[4][a]  2008–2009     85    $4,835,294
# 3  Beautiful Trauma World Tour  2018–2019    156    $2,546,795
# 4      Reputation Stadium Tour       2018     53    $6,522,173

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Actual gross                      20 non-null     object
#  1   Adjusted gross (in 2022 dollars)  20 non-null     object
#  2   Artist                            20 non-null     object
#  3   Tour title                        20 non-null     object
#  4   Year(s)                           20 non-null     object
#  5   Shows                             20 non-null     int64
#  6   Average gross                     20 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.2+ KB

# %%
df.columns.tolist()
# Out:
# ['Actual\xa0gross',
#  'Adjusted\xa0gross (in 2022 dollars)',
#  'Artist',
#  'Tour title',
#  'Year(s)',
#  'Shows',
#  'Average gross']

# %%
#Removing dollar signs
df['Actual\xa0gross'] = df['Actual\xa0gross'].str.replace('$', '').str.replace( ',', '')
df['Adjusted\xa0gross (in 2022 dollars)'] = df['Adjusted\xa0gross (in 2022 dollars)'].str.replace('$', '').str.replace( ',', '')
df['Average gross'] = df['Average gross'].str.replace('$', '').str.replace( ',', '')
df
# Out:
#     Actual gross Adjusted gross (in 2022 dollars)        Artist  \
# 0      780000000                        780000000  Taylor Swift
# 1      579800000                        579800000       Beyoncé
# 2      411000000                        560622615       Madonna
# 3      397300000                        454751555          Pink
# 4      345675146                        402844849  Taylor Swift
# 5      305158363                        388978496       Madonna
# 6      280000000                        381932682   Celine Dion
# 7      257600000                        257600000          Pink
# 8      256084556                        312258401       Beyoncé
# 9      250400000                        309141878  Taylor Swift
# 10  229100000[b]                        283202896       Beyoncé
# 11     227400000                        295301479     Lady Gaga
# 12     204000000                        251856802    Katy Perry
# 13     200000000                        299676265          Cher
# ...

# %%
#Renaming columns df = df.rename(columns={'Average gross':'Average Gross($)', 'Actual Gross': 'Actual gross ($)'})

# %%
#Changing Data Type 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Actual gross                      20 non-null     object
#  1   Adjusted gross (in 2022 dollars)  20 non-null     object
#  2   Artist                            20 non-null     object
#  3   Tour title                        20 non-null     object
#  4   Year(s)                           20 non-null     object
#  5   Shows                             20 non-null     int64
#  6   Average gross                     20 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.2+ KB

# %%
#df['Average gross'] =df['Average gross'].astype(int) 
df['Average gross'] =df['Average gross'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Actual gross                      20 non-null     object
#  1   Adjusted gross (in 2022 dollars)  20 non-null     object
#  2   Artist                            20 non-null     object
#  3   Tour title                        20 non-null     object
#  4   Year(s)                           20 non-null     object
#  5   Shows                             20 non-null     int64
#  6   Average gross                     20 non-null     int32
# dtypes: int32(1), int64(1), object(5)
# memory usage: 1.1+ KB

# %%
#regex
df['gross'] = df.gross.str.replace(r'[^/d.]','', regex =True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #regex
# ----> 2 df['gross'] = df.gross.str.replace(r'[^/d.]','', regex =True)
#
# NameError: name 'df' is not defined
